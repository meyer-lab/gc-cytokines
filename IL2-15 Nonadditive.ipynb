# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('png', 'pdf')
from ckine.simulation_plotting import solve_IL2_IL15

# %%
active_matrix, num, xaxis = solve_IL2_IL15(1.0, 50, 240.0)
f, ax = plt.subplots()
ax.plot(xaxis, active_matrix[0], 'b', label = 'IL2 Activity')
ax.plot(xaxis, active_matrix[1], 'r', label = 'IL15 Activity')
ax.plot(xaxis, active_matrix[2], 'k', label = 'Total Activity')
ax.set_xlabel('Log(IL2/IL15)')
ax.set_ylabel('Activity')
ax.set_ylim(bottom = 0)
ax.set_title('Non-additive effects between IL2/15 in YT-1 cells (1nM)')
ax.legend()

# %%
active_matrix, num, xaxis = solve_IL2_IL15(500.0, 50, 240.0)
f, ax = plt.subplots()
ax.plot(xaxis, active_matrix[0], 'b', label = 'IL2 Activity')
ax.plot(xaxis, active_matrix[1], 'r', label = 'IL15 Activity')
ax.plot(xaxis, active_matrix[2], 'k', label = 'Total Activity')
ax.set_xlabel('Log(IL2/IL15)')
ax.set_ylabel('Activity')
ax.set_ylim(bottom = 0)
ax.set_title('Non-additive effects between IL2/15 in YT-1 cells (500nM)')
ax.legend()
